# %% [markdown]
# <a href="https://colab.research.google.com/github/FG2511/ARE/blob/master/model1_cross_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
@File name: model1.ipynb
@Created on 2018-12-20
@Authors: Federica Gerina, Francesca Moi, Silvia Maria Massa
@Description: Given a time-series dataset that contains minute-by-minute data 
about different kind of gases, collected by the uHoo air quality sensor, train
a NN that classifies if a minute belongs to the class "Pasto" (1) otherwise to
the class "Other" (0).
'''

# !pip install liac-arff

import arff
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import legend
from pandas import DataFrame
from pandas import read_csv
from pandas import concat
from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU
from keras.preprocessing import sequence
from keras import optimizers
from sklearn.utils import compute_class_weight
from keras.models import load_model
from sklearn.model_selection import StratifiedKFold

# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# Out:
# Requirement already satisfied: liac-arff in /usr/local/lib/python3.6/dist-packages (2.3.1)

# %%
def generate_model(shape):
  
  model = Sequential()
  '''
  model.add(Dense(32, input_dim=shape, kernel_initializer='random_uniform',  bias_initializer='zeros', activation='tanh'))
  model.add(Dropout(0.5))
  model.add(Dense(64, kernel_initializer='random_uniform',  bias_initializer='zeros', activation='tanh'))
  model.add(Dropout(0.5))
  model.add(Dense(128, kernel_initializer='random_uniform',  bias_initializer='zeros', activation='tanh'))
  model.add(Dropout(0.5))
  model.add(Dense(256, kernel_initializer='random_uniform',  bias_initializer='zeros', activation='tanh'))
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))
  print(model.summary())
  '''
  model.add(Dense(32, input_dim=shape, kernel_initializer='random_uniform',  bias_initializer='zeros'))
  model.add(LeakyReLU(alpha = 0.5))
  model.add(Dropout(0.5))
  model.add(Dense(64, kernel_initializer='random_uniform',  bias_initializer='zeros'))
  model.add(LeakyReLU(alpha = 0.5))
  model.add(Dropout(0.5))
  model.add(Dense(128, kernel_initializer='random_uniform',  bias_initializer='zeros'))
  model.add(LeakyReLU(alpha = 0.5))
  model.add(Dropout(0.5))
  model.add(Dense(256, kernel_initializer='random_uniform',  bias_initializer='zeros'))
  model.add(LeakyReLU(alpha = 0.5))
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))
  #print(model.summary())

  return model

# %%
#LOAD DATA
print("Loading data...")

dataset = '/root/data/Half_uHoo_featureDataset.arff'

with open (dataset, encoding='utf-8') as f:
  dataDictionary = arff.load(f)

data = np.array(dataDictionary['data'])
print("DATASET LOADED")

#CONVERTING VALUES
print("Converting values...")
for i in data:
  if(i[-1] == 'Other'): i[-1] = 0
  elif(i[-1] == 'Pasto') : i[-1] = 1

dataset = data.astype('float32')
print("CONVERSION DONE")

#SPLIT INTO INPUT (X) AND OUTPUT (Y) VARIABLES
s = dataset.shape[-1]
X = dataset[:,0:s-1]
Y = dataset[:,s-1]
# Out:
# Loading data...
# DATASET LOADED
# Converting values...
# CONVERSION DONE

# %%
#OPTIMIZERS
sgd = optimizers.SGD(lr=0.0001)
rms = optimizers.RMSprop(lr=0.001)
adm = optimizers.Adam(lr=0.001)

#DEFINE 10-FOLD CROSS-VALIDATION
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []

for train, test in kfold.split(X, Y):
  
  #COMPUTE CLASS WEIGHT
  labels = np.unique(Y[train])
  classWeight = compute_class_weight('balanced', labels, Y[train])
  classWeight = dict(zip(labels,classWeight))

  #GENERATE MODEL
  model = generate_model(X[train].shape[-1])

  #COMPILE MODEL
  model.compile(loss='binary_crossentropy', optimizer = adm , metrics=['accuracy'])

  #FIT MODEL
  history = model.fit(X[train], Y[train], epochs=3, validation_split=0.33, batch_size = 128, shuffle = True, verbose=1, class_weight = classWeight)

  #EVALUATE MODEL
  scores_test = model.evaluate(X[test], Y[test], batch_size=128, verbose = 1)
  print("Test loss: %.2f%%" % (scores_test[0] * 100))
  print("Test accuracy: %.2f%%" % (scores_test[1] * 100))
  
  cvscores.append(scores_test[1] * 100)

print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_56 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_57 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_58 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_59 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88410 samples, validate on 43546 samples
# Epoch 1/3
# 88410/88410 [==============================] - 6s 68us/step - loss: 0.7267 - acc: 0.5459 - val_loss: 0.4649 - val_acc: 0.4896
# Epoch 2/3
# 88410/88410 [==============================] - 4s 49us/step - loss: 0.6453 - acc: 0.5687 - val_loss: 0.4406 - val_acc: 0.6149
# Epoch 3/3
# 88410/88410 [==============================] - 4s 49us/step - loss: 0.6324 - acc: 0.5643 - val_loss: 0.4627 - val_acc: 0.3699
# 14663/14663 [==============================] - 0s 13us/step
# Test loss: 67.74%
# Test accuracy: 39.81%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_61 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_62 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_64 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88410 samples, validate on 43546 samples
# Epoch 1/3
# 88410/88410 [==============================] - 6s 70us/step - loss: 0.9528 - acc: 0.5188 - val_loss: 0.5227 - val_acc: 0.4750
# Epoch 2/3
# 88410/88410 [==============================] - 4s 51us/step - loss: 0.6588 - acc: 0.5908 - val_loss: 0.4370 - val_acc: 0.6630
# Epoch 3/3
# 88410/88410 [==============================] - 5s 54us/step - loss: 0.6386 - acc: 0.5913 - val_loss: 0.4179 - val_acc: 0.8498
# 14663/14663 [==============================] - 0s 15us/step
# Test loss: 48.95%
# Test accuracy: 83.66%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_67 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_68 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88410 samples, validate on 43546 samples
# Epoch 1/3
# 88410/88410 [==============================] - 7s 79us/step - loss: 9.3114 - acc: 0.9172 - val_loss: 4.9929 - val_acc: 0.9721
# Epoch 2/3
# 88410/88410 [==============================] - 5s 52us/step - loss: 9.5699 - acc: 0.9465 - val_loss: 4.9929 - val_acc: 0.9721
# Epoch 3/3
# 88410/88410 [==============================] - 4s 51us/step - loss: 9.5697 - acc: 0.9466 - val_loss: 4.9929 - val_acc: 0.9721
# 14663/14663 [==============================] - 0s 13us/step
# Test loss: 72.55%
# Test accuracy: 95.50%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_71 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_72 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_73 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_74 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88411 samples, validate on 43546 samples
# Epoch 1/3
# 88411/88411 [==============================] - 6s 72us/step - loss: 9.4384 - acc: 0.9307 - val_loss: 4.9797 - val_acc: 0.9722
# Epoch 2/3
# 88411/88411 [==============================] - 5s 51us/step - loss: 9.5759 - acc: 0.9465 - val_loss: 4.9797 - val_acc: 0.9722
# Epoch 3/3
# 88411/88411 [==============================] - 4s 50us/step - loss: 9.5761 - acc: 0.9465 - val_loss: 4.9797 - val_acc: 0.9722
# 14662/14662 [==============================] - 0s 13us/step
# Test loss: 72.44%
# Test accuracy: 95.51%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_76 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_77 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_78 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_79 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_80 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88411 samples, validate on 43546 samples
# Epoch 1/3
# 88411/88411 [==============================] - 7s 75us/step - loss: 9.2663 - acc: 0.9199 - val_loss: 5.0250 - val_acc: 0.9720
# Epoch 2/3
# 88411/88411 [==============================] - 4s 49us/step - loss: 9.5540 - acc: 0.9466 - val_loss: 5.0250 - val_acc: 0.9720
# Epoch 3/3
# 88411/88411 [==============================] - 4s 49us/step - loss: 9.5501 - acc: 0.9465 - val_loss: 5.0250 - val_acc: 0.9720
# 14662/14662 [==============================] - 0s 13us/step
# Test loss: 72.44%
# Test accuracy: 95.51%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_81 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_82 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_83 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_84 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_85 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88411 samples, validate on 43546 samples
# Epoch 1/3
# 88411/88411 [==============================] - 7s 74us/step - loss: 9.4288 - acc: 0.9365 - val_loss: 5.0373 - val_acc: 0.9719
# Epoch 2/3
# 88411/88411 [==============================] - 5s 52us/step - loss: 9.5475 - acc: 0.9467 - val_loss: 5.0373 - val_acc: 0.9719
# Epoch 3/3
# 88411/88411 [==============================] - 4s 50us/step - loss: 9.5474 - acc: 0.9467 - val_loss: 5.0373 - val_acc: 0.9719
# 14662/14662 [==============================] - 0s 13us/step
# Test loss: 72.44%
# Test accuracy: 95.51%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_86 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_87 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_88 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_89 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_90 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88411 samples, validate on 43547 samples
# Epoch 1/3
# 88411/88411 [==============================] - 7s 75us/step - loss: 0.9943 - acc: 0.5350 - val_loss: 0.4535 - val_acc: 0.7271
# Epoch 2/3
# 88411/88411 [==============================] - 4s 50us/step - loss: 0.6604 - acc: 0.6100 - val_loss: 0.4777 - val_acc: 0.4545
# Epoch 3/3
# 88411/88411 [==============================] - 4s 50us/step - loss: 0.6461 - acc: 0.6061 - val_loss: 0.4525 - val_acc: 0.4648
# 14661/14661 [==============================] - 0s 15us/step
# Test loss: 67.55%
# Test accuracy: 46.37%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_91 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_92 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_93 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_94 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_95 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88411 samples, validate on 43547 samples
# Epoch 1/3
# 88411/88411 [==============================] - 7s 78us/step - loss: 8.7783 - acc: 0.8428 - val_loss: 5.0455 - val_acc: 0.9718
# Epoch 2/3
# 88411/88411 [==============================] - 4s 50us/step - loss: 9.5444 - acc: 0.9466 - val_loss: 5.0455 - val_acc: 0.9718
# Epoch 3/3
# 88411/88411 [==============================] - 4s 49us/step - loss: 9.5435 - acc: 0.9467 - val_loss: 5.0455 - val_acc: 0.9718
# 14661/14661 [==============================] - 0s 14us/step
# Test loss: 72.45%
# Test accuracy: 95.51%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_96 (Dense)             (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_97 (Dense)             (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_98 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_99 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_100 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88411 samples, validate on 43547 samples
# Epoch 1/3
# 88411/88411 [==============================] - 7s 79us/step - loss: 9.2026 - acc: 0.8724 - val_loss: 4.9838 - val_acc: 0.9722
# Epoch 2/3
# 88411/88411 [==============================] - 5s 51us/step - loss: 9.5751 - acc: 0.9464 - val_loss: 4.9838 - val_acc: 0.9722
# Epoch 3/3
# 88411/88411 [==============================] - 4s 49us/step - loss: 9.5729 - acc: 0.9464 - val_loss: 4.9838 - val_acc: 0.9722
# 14661/14661 [==============================] - 0s 14us/step
# Test loss: 72.45%
# Test accuracy: 95.51%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_101 (Dense)            (None, 32)                3648
# _________________________________________________________________
# leaky_re_lu_81 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_102 (Dense)            (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_82 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_103 (Dense)            (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_104 (Dense)            (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_105 (Dense)            (None, 1)                 257
# =================================================================
# Total params: 47,361
# Trainable params: 47,361
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 88411 samples, validate on 43547 samples
# Epoch 1/3
# 88411/88411 [==============================] - 7s 81us/step - loss: 9.3269 - acc: 0.8979 - val_loss: 5.0043 - val_acc: 0.9721
# Epoch 2/3
# 88411/88411 [==============================] - 5s 51us/step - loss: 9.5638 - acc: 0.9466 - val_loss: 5.0043 - val_acc: 0.9721
# Epoch 3/3
# 88411/88411 [==============================] - 5s 51us/step - loss: 9.5636 - acc: 0.9466 - val_loss: 5.0043 - val_acc: 0.9721
# 14661/14661 [==============================] - 0s 14us/step
# Test loss: 72.45%
# Test accuracy: 95.51%
# 83.84% (+/- 20.72%)

# %%
model.save('my_model1_cv.h5')

#model = load_model('my_model1_cv.h5')
